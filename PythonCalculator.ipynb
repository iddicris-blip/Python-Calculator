# %% [markdown]
# <a href="https://colab.research.google.com/github/iddicris-blip/Python-Calculator/blob/main/PythonCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculator(num1, num2):
    print(f"Calculating with: {num1} and {num2}")

    valid_operators = ['+', '-', '*', '/']

    while True:
        operator = input("Enter the operator (+, -, *, /): ").strip()

        if operator in valid_operators:
            break
        else:
            print("Invalid operator! Please enter one of: +, -, *, /")


    if operator == '+':
        result = num1 + num2

    elif operator == '-':
        result = num1 - num2

    elif operator == '*':
        result = num1 * num2

    elif operator == '/':
        if num2 == 0:
            return "Error: Cannot divide by zero!"
        result = num1 / num2


    return result


def get_number(prompt):
    while True:
        try:
            number = float(input(prompt))
            return number
        except ValueError:
            print("Invalid input! Please enter a valid number.")


def main():

    while True:
        print("--- New Calculation ---")

        num1 = get_number("Enter the first number: ")
        num2 = get_number("Enter the second number: ")

        result = calculator(num1, num2)
        print(f"The result is: {result}")

        while True:
            continue_choice = input("Do you want to perform another calculation? (y/n): ").strip().lower()
            if continue_choice in ['y', 'yes', 'n', 'no']:
                break


        if continue_choice in ['n', 'no']:
            print("\nThank you for using the calculator. Goodbye!")
            break

if __name__ == "__main__":
    main()
# Out:
# --- New Calculation ---
# Enter the first number: 5
# Enter the second number: 5
# Calculating with: 5.0 and 5.0
# Enter the operator (+, -, *, /): +
# The result is: 10.0
# Do you want to perform another calculation? (y/n): n
#
# Thank you for using the calculator. Goodbye!

# %%
main()
# Out:
# --- New Calculation ---
# Enter the first number: 7
# Enter the second number: 9
# Calculating with: 7.0 and 9.0
# Enter the operator (+, -, *, /): -
# The result is: -2.0
# Do you want to perform another calculation? (y/n): n
#
# Thank you for using the calculator. Goodbye!
